# %%
pip install yfinance scikit-learn
# Out:
# Collecting yfinance
#   Downloading yfinance-1.4.1-py2.py3-none-any.whl.metadata (6.2 kB)
# Requirement already satisfied: scikit-learn in C:\Users\ADMIN\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (1.9.0)
# Requirement already satisfied: pandas>=1.3.0 in C:\Users\ADMIN\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from yfinance) (3.0.2)
# Requirement already satisfied: numpy>=1.16.5 in C:\Users\ADMIN\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from yfinance) (2.4.4)
# Requirement already satisfied: requests>=2.31 in C:\Users\ADMIN\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from yfinance) (2.33.1)
# Collecting multitasking>=0.0.7 (from yfinance)
#   Downloading multitasking-0.0.13-py3-none-any.whl.metadata (16 kB)
# Requirement already satisfied: platformdirs>=2.0.0 in C:\Users\ADMIN\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from yfinance) (4.9.6)
# Collecting pytz>=2022.5 (from yfinance)
#   Downloading pytz-2026.2-py2.py3-none-any.whl.metadata (22 kB)
# Collecting peewee>=3.16.2 (from yfinance)
#   Downloading peewee-4.1.0-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: beautifulsoup4>=4.11.1 in C:\Users\ADMIN\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from yfinance) (4.14.3)
# Collecting curl_cffi>=0.15 (from yfinance)
#   Downloading curl_cffi-0.15.0-cp310-abi3-win_amd64.whl.metadata (18 kB)
# Requirement already satisfied: protobuf>=3.19.0 in C:\Users\ADMIN\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from yfinance) (7.34.1)
# Requirement already satisfied: websockets>=13.0 in C:\Users\ADMIN\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from yfinance) (16.0)
# Requirement already satisfied: scipy>=1.10.0 in C:\Users\ADMIN\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from scikit-learn) (1.18.0)
# Requirement already satisfied: joblib>=1.4.0 in C:\Users\ADMIN\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from scikit-learn) (1.5.3)
# Requirement already satisfied: narwhals>=2.0.1 in C:\Users\ADMIN\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from scikit-learn) (2.21.2)
# Requirement already satisfied: threadpoolctl>=3.5.0 in C:\Users\ADMIN\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from scikit-learn) (3.6.0)
# Requirement already satisfied: soupsieve>=1.6.1 in C:\Users\ADMIN\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from beautifulsoup4>=4.11.1->yfinance) (2.8.3)
# Requirement already satisfied: typing-extensions>=4.0.0 in C:\Users\ADMIN\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from beautifulsoup4>=4.11.1->yfinance) (4.15.0)
# Requirement already satisfied: cffi>=2.0.0 in C:\Users\ADMIN\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from curl_cffi>=0.15->yfinance) (2.0.0)
# Requirement already satisfied: certifi>=2024.2.2 in C:\Users\ADMIN\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from curl_cffi>=0.15->yfinance) (2026.4.22)
# Requirement already satisfied: rich in C:\Users\ADMIN\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from curl_cffi>=0.15->yfinance) (15.0.0)
# Requirement already satisfied: pycparser in C:\Users\ADMIN\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from cffi>=2.0.0->curl_cffi>=0.15->yfinance) (3.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in C:\Users\ADMIN\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from pandas>=1.3.0->yfinance) (2.9.0.post0)
# Requirement already satisfied: tzdata in C:\Users\ADMIN\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from pandas>=1.3.0->yfinance) (2026.2)
# Requirement already satisfied: six>=1.5 in C:\Users\ADMIN\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from python-dateutil>=2.8.2->pandas>=1.3.0->yfinance) (1.17.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in C:\Users\ADMIN\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from requests>=2.31->yfinance) (3.4.7)
# Requirement already satisfied: idna<4,>=2.5 in C:\Users\ADMIN\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from requests>=2.31->yfinance) (3.13)
# Requirement already satisfied: urllib3<3,>=1.26 in C:\Users\ADMIN\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from requests>=2.31->yfinance) (2.6.3)
# Requirement already satisfied: markdown-it-py>=2.2.0 in C:\Users\ADMIN\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from rich->curl_cffi>=0.15->yfinance) (4.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in C:\Users\ADMIN\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from rich->curl_cffi>=0.15->yfinance) (2.20.0)
# Requirement already satisfied: mdurl~=0.1 in C:\Users\ADMIN\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from markdown-it-py>=2.2.0->rich->curl_cffi>=0.15->yfinance) (0.1.2)
# Downloading yfinance-1.4.1-py2.py3-none-any.whl (137 kB)
# Downloading curl_cffi-0.15.0-cp310-abi3-win_amd64.whl (1.7 MB)
#    ---------------------------------------- 0.0/1.7 MB ? eta -:--:--
#    ------ --------------------------------- 0.3/1.7 MB ? eta -:--:--
#    ------------ --------------------------- 0.5/1.7 MB 1.3 MB/s eta 0:00:01
#    ------------------ --------------------- 0.8/1.7 MB 1.6 MB/s eta 0:00:01
#    ------------------------------- -------- 1.3/1.7 MB 1.9 MB/s eta 0:00:01
#    ---------------------------------------- 1.7/1.7 MB 2.0 MB/s  0:00:00
# Downloading multitasking-0.0.13-py3-none-any.whl (16 kB)
# Downloading peewee-4.1.0-py3-none-any.whl (155 kB)
# Downloading pytz-2026.2-py2.py3-none-any.whl (510 kB)
# Installing collected packages: pytz, peewee, multitasking, curl_cffi, yfinance
#
#    ---------------------------------------- 0/5 [pytz]
#    ---------------------------------------- 0/5 [pytz]
#    ---------------------------------------- 0/5 [pytz]
#    -------- ------------------------------- 1/5 [peewee]
#    -------- ------------------------------- 1/5 [peewee]
#    -------- ------------------------------- 1/5 [peewee]
#    ------------------------ --------------- 3/5 [curl_cffi]
#    ------------------------ --------------- 3/5 [curl_cffi]
#    ------------------------ --------------- 3/5 [curl_cffi]
#    -------------------------------- ------- 4/5 [yfinance]
#    -------------------------------- ------- 4/5 [yfinance]
#    -------------------------------- ------- 4/5 [yfinance]
#    ---------------------------------------- 5/5 [yfinance]
#
# Successfully installed curl_cffi-0.15.0 multitasking-0.0.13 peewee-4.1.0 pytz-2026.2 yfinance-1.4.1
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 26.1.1 -> 26.1.2
# [notice] To update, run: C:\Users\ADMIN\AppData\Local\Python\pythoncore-3.14-64\python.exe -m pip install --upgrade pip

# %%
import yfinance as yf
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
import matplotlib.pyplot as plt

df = yf.download("AAPL", start="2020-01-01", end="2025-01-01")

df = df[['Open', 'High', 'Low', 'Volume', 'Close']].dropna()

X = df[['Open', 'High', 'Low', 'Volume']]
y = df['Close']

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, shuffle=False)

model = LinearRegression()
model.fit(X_train, y_train)

pred = model.predict(X_test)

plt.plot(y_test.values, label="Actual")
plt.plot(pred, label="Predicted")
plt.legend()
plt.title("Stock Prediction")
plt.show()
# Out:
# [*********************100%***********************]  1 of 1 completed
